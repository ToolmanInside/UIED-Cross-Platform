# %%
from match_elements.GUI_pair import GUIPair
import cv2
from matplotlib import pyplot as plt
from random import randint as rint
from difflib import SequenceMatcher

# %%
gui = GUIPair('0001')

# %%
gui.element_detection(True, True, True)
# Out:
# [D 211112 15:27:34 text_detection:174] start detection
# [D 211112 15:27:34 text_detection:188] send image request
# [D 211112 15:27:34 text_detection:191] detection result received
# [D 211112 15:27:34 text_detection:174] start detection
# [D 211112 15:27:34 text_detection:188] send image request
# [Text Detection Completed in 0.173 s] Input: data/input/A0001.jpg Output: data/output/ocr/A0001.json
# [D 211112 15:27:35 text_detection:191] detection result received
# [Text Detection Completed in 0.214 s] Input: data/input/I0001.png Output: data/output/ocr/I0001.json
# [Compo Detection Completed in 0.704 s] Input: data/input/A0001.jpg Output: data/output/ip/A0001.json
# [Compo Detection Completed in 0.760 s] Input: data/input/I0001.png Output: data/output/ip/I0001.json
# [Merge Completed] Input: data/input/A0001.jpg Output: data/output/merge/A0001.jpg
# [Merge Completed] Input: data/input/I0001.png Output: data/output/merge/I0001.jpg

# %%
gui.load_detection_result()

# %%
gui.show_detection_result()
# Out:
# No detection result, run element_detection() or load_detection_result() first

# %%
gui.match_similar_elements()

# %%
gui.visualize_matched_element_pairs()
# Out:
# [D 211112 15:27:44 GUI_pair:190] [[[ 79  89  72]
#       [ 79  89  72]
#       [ 79  89  72]
#       ...
#       [ 79  89  72]
#       [ 79  89  72]
#       [ 79  89  72]]
#
#      [[ 79  89  72]
#       [ 79  89  72]
#       [ 79  89  72]
#       ...
#       [ 79  89  72]
#       [ 79  89  72]
#       [ 79  89  72]]
#
#      [[ 79  89  72]
#       [ 79  89  72]
#       [ 79  89  72]
#       ...
#       [ 79  89  72]
#       [ 79  89  72]
#       [ 79  89  72]]
#
#      ...
#
#      [[255 255 255]
#       [255 255 255]
#       [255 255 255]
#       ...
#       [255 255 255]
#       [255 255 255]
#       [255 255 255]]
#
#      [[255 255 255]
#       [255 255 255]
#       [255 255 255]
#       ...
#       [255 255 255]
#       [255 255 255]
#       [255 255 255]]
#
#      [[255 255 255]
#       [255 255 255]
#       [255 255 255]
#       ...
#       [255 255 255]
#       [255 255 255]
#       [255 255 255]]]
